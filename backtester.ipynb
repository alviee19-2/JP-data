# %%
# %matplotlib inline
import quantstats as qs

# %%
print(type(qs.extend_pandas()))
# Out:
# <class 'NoneType'>

# %%
stock = qs.utils.download_returns('META')

# %%
print(type(stock))
# Out:
# <class 'pandas.core.series.Series'>

# %%
qs.stats.sharpe(stock)
# Out:
# 0.7721567517354818

# %%
print(stock.sharpe())
print(qs.stats.(stock))
# Out:
# 0.7721567517354818
# 0.39998118812116124

# %%
qs.plots.snapshot(stock, title='Facebook Performance', show=True, figsize=(26, 18))

# can also be called via:
# stock.plot_snapshot(title='Facebook Performance', show=True)

# %%
qs.reports.metrics(stock, mode="basic")
# Out:
#                      Strategy
# -------------------  ----------
# Start Period         2012-05-21
# End Period           2025-08-04
# Risk-Free Rate       0.0%
# Time in Market       100.0%
#
# Cumulative Return    1,941.93%
# CAGR﹪               17.07%
#
# Sharpe               0.77
# Prob. Sharpe Ratio   99.76%
# Sortino              1.15
# Sortino/√2           0.82
# Omega                1.16
#
# Max Drawdown         -76.74%
# Max DD Date          2022-11-03
# Max DD Period Start  2021-09-08
# Max DD Period End    2024-01-18
# Longest DD Days      863
#
# Gain/Pain Ratio      0.16
# Gain/Pain (1M)       0.91
#
# Payoff Ratio         1.05
# Profit Factor        1.16
# Common Sense Ratio   1.15
# CPC Index            0.64
# Tail Ratio           0.99
# Outlier Win Ratio    3.91
# Outlier Loss Ratio   3.93
#
# MTD                  0.38%
# 3M                   30.14%
# 6M                   11.5%
# YTD                  32.82%
# 1Y                   59.59%
# 3Y (ann.)            45.54%
# ...

# %%
qs.reports.plots(stock, mode = "full")

# %%
qs.reports.basic(stock)
# Out:
# <h4>Performance Metrics</h4>
#                      Strategy
# -------------------  ----------
# Start Period         2012-05-21
# End Period           2025-08-04
# Risk-Free Rate       0.0%
# Time in Market       100.0%
#
# Cumulative Return    1,941.93%
# CAGR﹪               17.07%
#
# Sharpe               0.77
# Prob. Sharpe Ratio   99.76%
# Sortino              1.15
# Sortino/√2           0.82
# Omega                1.16
#
# Max Drawdown         -76.74%
# Max DD Date          2022-11-03
# Max DD Period Start  2021-09-08
# Max DD Period End    2024-01-18
# Longest DD Days      863
#
# Gain/Pain Ratio      0.16
# Gain/Pain (1M)       0.91
#
# Payoff Ratio         1.05
# Profit Factor        1.16
# Common Sense Ratio   1.15
# CPC Index            0.64
# Tail Ratio           0.99
# Outlier Win Ratio    3.91
# Outlier Loss Ratio   3.93
#
# MTD                  0.38%
# 3M                   30.14%
# 6M                   11.5%
# YTD                  32.82%
# 1Y                   59.59%
# ...

# %%
qs.reports.html(stock)
# Out:
# <script> var bl=new Blob(['<!-- generated by QuantStats for Python --><!DOCTYPE html><html lang="en"><head> <meta charset="utf-8"> <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"> <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"> <title>Tearsheet (generated by QuantStats)</title> <meta name="robots" content="noindex, nofollow"> <link rel="shortcut icon" href="https://qtpylib.io/favicon.ico" type="image/x-icon"> <style> body{-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;margin:30px}body,p,table,td,th{font:13px/1.4 Arial,sans-serif}.container{max-width:960px;margin:auto}img,svg{width:100%}h1,h2,h3,h4{font-weight:400;margin:0}h1 dt{display:inline;margin-left:10px;font-size:14px}h3{margin-bottom:10px;font-weight:700}h4{color:grey}h4 a{color:#09c;text-decoration:none}h4 a:hover{color:#069;text-decoration:underline}hr{margin:25px 0 40px;height:0;border:0;border-top:1px solid #ccc}#left{width:620px;margin-right:18px;m
# ...
